# %% [markdown]
# # MLTSA vs Feature Permutations
#
# ###### *Note that this Jupyter Notebook requires you to have the MLTSA package installed.

# %% [markdown]
# As usual with MLTSA experiments we first create the 1D analytical model dataset.

# %%
"""First we import our dataset examples"""
from MLTSA_datasets.OneD_pot.OneD_pot_data import potentials #We import the potentials class which will define them.
from MLTSA_datasets.OneD_pot.OneD_pot_data import dataset #We import the dataset class which will hold our potentials.
import matplotlib.pyplot as plt
import numpy as np

#This cell sets the potentials, don't re-run
total_n_pots = 25
n_DW = 5
relevant_DW_n = 2
#After defining the desired parameters we define the potentials accordingly
pots = potentials(total_n_pots, n_DW, relevant_DW_n)
# This creates the first dataset of data.
n_features = 180
degree_of_mixing = 2
#We specified the number of features wanted and how much they will mix
oneD_dataset = dataset(pots, n_features, degree_of_mixing)
# Out:
# Defining Potentials: 100%|###########################################################| 25/25 [00:00<00:00, 1667.58it/s]

# %% [markdown]
# Once the dataset has been created we generate the data we will use over the comparison

# %%
"""Now we generate the trajectories we will use for the whole experiment"""
#Generate the trajectories
n_simulations = 100
n_steps = 250
data, ans = oneD_dataset.generate_linear(n_simulations, n_steps)
data_val, ans_val = oneD_dataset.generate_linear(int(n_simulations/2), n_steps)

#Prepare it for training
time_frame = [30, 60] #Same time frame as the sklearn one
X, Y = oneD_dataset.PrepareData(data, ans, time_frame, mode="Normal")
X_val, Y_val = oneD_dataset.PrepareData(data_val, ans_val, time_frame, mode="Normal")
# Out:
# Running Simulations: 100%|###########################################################| 100/100 [00:19<00:00,  5.07it/s]
# Classifying Simulation Outcomes: 100%|###########################################| 100/100 [00:00<00:00, 100198.38it/s]
# Running Simulations: 100%|#############################################################| 50/50 [00:09<00:00,  5.28it/s]
# Classifying Simulation Outcomes: 100%|#########################################################| 50/50 [00:00<?, ?it/s]
# Generating dataset
# Getting simulation labels for the generated data
# Generating dataset
# Getting simulation labels for the generated data

# %%
from MLTSA_sklearn.models import SKL_Train
from sklearn.neural_network import MLPClassifier
from MLTSA_sklearn.MLTSA_sk import MLTSA
from sklearn.inspection import permutation_importance

#For loop for MLTSA and Permutation on MLP

replicas = 100

results = {}
results["MLTSA"] = []
results["Perm"] = []
results["NN"] = []
results["acc"] = []


for R in range(replicas):

    NN = MLPClassifier(random_state=0, verbose=False, max_iter=500)
    trained_NN, train_acc, test_acc = SKL_Train(NN, X, Y)

    feat_perm = permutation_importance(trained_NN, X, Y, n_repeats=10, random_state=0)

    ADrop_train_avg = MLTSA(data[:,:,time_frame[0]:time_frame[1]], ans, trained_NN, drop_mode="Average")

    results["MLTSA"].append(ADrop_train_avg)
    results["Perm"].append(feat_perm)
    results["NN"].append(trained_NN)
    results["acc"].append([train_acc, test_acc])
# Out:
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.723722219467163 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.208152055740356 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.810606718063354 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.349275588989258 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  9.417754173278809 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.960005283355713 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.242988348007202 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.79642653465271 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.042953729629517 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.425757884979248 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.859591960906982 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  12.216459035873413 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  12.039567708969116 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  11.619826555252075 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  9.139358282089233 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  11.19708800315857 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  11.091153383255005 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  11.344996213912964 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  11.193090438842773 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  11.198087215423584 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  11.212078094482422 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  11.197088718414307 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  9.68204140663147 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.299877166748047 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.3408522605896 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.056026697158813 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.8441572189331055 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.809698581695557 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.9221107959747314 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.857150554656982 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.819173336029053 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.760208606719971 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.95808744430542 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.834162950515747 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.849157094955444 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.793187856674194 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.92973518371582 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.101998567581177 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.90212345123291 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.958088636398315 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  9.177336692810059 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.734222888946533 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.811176538467407 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.919111490249634 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.831165790557861 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.761207342147827 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.696249485015869 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.879136800765991 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.923110723495483 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.757211446762085 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.775198459625244 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.808178663253784 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.816176652908325 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.858150482177734 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.771204233169556 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.105994939804077 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.844161033630371 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.8331663608551025 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.969081878662109 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.226921558380127 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.804184913635254 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.850153684616089 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.810177803039551 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.8811354637146 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.901124477386475 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.922109842300415 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.882134675979614 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.804183483123779 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.8671441078186035 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.830165863037109 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.843160390853882 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.82916784286499 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.843161106109619 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.794188976287842 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.835163354873657 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.754214286804199 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.9740777015686035 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.767205476760864 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.894125461578369 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.903125047683716 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.966083288192749 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.857093334197998 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.98007345199585 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.900121688842773 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.805182695388794 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.872140407562256 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.805182933807373 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.784194231033325 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.803182125091553 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.75921106338501 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.771204948425293 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.973078727722168 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.78919243812561 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  8.003061056137085 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.9211084842681885 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.791191339492798 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.7991859912872314 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.910116195678711 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.9900665283203125 seconds
# Accuracy on Train is 88.62222222222222
# Accuracy on Test set is 88.13333333333333
# Trained in  7.850154161453247 seconds
# 100it [00:08, 12.48it/s]
# 100it [00:07, 12.85it/s]
# 100it [00:08, 12.29it/s]
# 100it [00:08, 11.68it/s]
# 100it [00:08, 11.95it/s]
# 100it [00:08, 12.11it/s]
# 100it [00:07, 13.22it/s]
# 100it [00:07, 12.98it/s]
# 100it [00:07, 13.40it/s]
# 100it [00:07, 13.20it/s]
# 100it [00:10,  9.13it/s]
# 100it [00:11,  8.91it/s]
# 100it [00:11,  9.03it/s]
# 100it [00:07, 12.53it/s]
# 100it [00:10,  9.15it/s]
# 100it [00:10,  9.27it/s]
# 100it [00:10,  9.30it/s]
# 100it [00:10,  9.37it/s]
# 100it [00:10,  9.32it/s]
# 100it [00:10,  9.22it/s]
# 100it [00:10,  9.34it/s]
# 100it [00:10,  9.30it/s]
# 100it [00:07, 12.78it/s]
# 100it [00:07, 12.78it/s]
# 100it [00:07, 13.50it/s]
# 100it [00:07, 12.58it/s]
# 100it [00:07, 13.19it/s]
# 100it [00:07, 13.08it/s]
# 100it [00:07, 13.07it/s]
# 100it [00:07, 13.45it/s]
# 100it [00:07, 13.31it/s]
# 100it [00:07, 12.81it/s]
# 100it [00:07, 13.09it/s]
# 100it [00:07, 13.16it/s]
# 100it [00:07, 13.32it/s]
# 100it [00:07, 13.38it/s]
# 100it [00:07, 13.39it/s]
# 100it [00:07, 13.51it/s]
# 100it [00:07, 13.52it/s]
# 100it [00:08, 11.79it/s]
# 100it [00:07, 13.17it/s]
# 100it [00:07, 13.33it/s]
# 100it [00:07, 12.98it/s]
# 100it [00:07, 12.91it/s]
# 100it [00:07, 13.16it/s]
# 100it [00:07, 13.25it/s]
# 100it [00:07, 13.12it/s]
# 100it [00:07, 13.59it/s]
# 100it [00:07, 13.39it/s]
# 100it [00:07, 13.27it/s]
# 100it [00:07, 12.75it/s]
# 100it [00:07, 13.25it/s]
# 100it [00:07, 13.25it/s]
# 100it [00:07, 13.11it/s]
# 100it [00:07, 13.45it/s]
# 100it [00:07, 13.39it/s]
# 100it [00:07, 13.08it/s]
# 100it [00:07, 13.20it/s]
# 100it [00:07, 13.10it/s]
# 100it [00:07, 13.43it/s]
# 100it [00:07, 13.44it/s]
# 100it [00:07, 13.43it/s]
# 100it [00:07, 13.71it/s]
# 100it [00:07, 13.13it/s]
# 100it [00:07, 13.28it/s]
# 100it [00:07, 13.35it/s]
# 100it [00:07, 13.15it/s]
# 100it [00:07, 13.19it/s]
# 100it [00:07, 12.81it/s]
# 100it [00:07, 13.17it/s]
# 100it [00:07, 13.29it/s]
# 100it [00:07, 13.62it/s]
# 100it [00:07, 13.39it/s]
# 100it [00:07, 13.02it/s]
# 100it [00:07, 13.20it/s]
# 100it [00:07, 13.39it/s]
# 100it [00:07, 13.24it/s]
# 100it [00:07, 13.29it/s]
# 100it [00:07, 13.31it/s]
# 100it [00:07, 13.47it/s]
# 100it [00:07, 13.29it/s]
# 100it [00:07, 13.39it/s]
# 100it [00:07, 13.41it/s]
# 100it [00:07, 13.43it/s]
# 100it [00:07, 13.42it/s]
# 100it [00:07, 13.43it/s]
# 100it [00:07, 13.36it/s]
# 100it [00:07, 13.34it/s]
# 100it [00:07, 13.27it/s]
# 100it [00:07, 13.31it/s]
# 100it [00:07, 13.35it/s]
# 100it [00:07, 13.18it/s]
# 100it [00:07, 13.39it/s]
# 100it [00:07, 13.28it/s]
# 100it [00:07, 13.15it/s]
# 100it [00:07, 13.39it/s]
# 100it [00:07, 13.27it/s]
# 100it [00:07, 13.49it/s]
# 100it [00:07, 13.28it/s]
# 100it [00:07, 13.01it/s]

# %%
acc = np.array(results["acc"])
adrop = np.array(results["MLTSA"])
permut = np.array(results["Perm"])
permut = [ x.importances_mean for x in permut]

plt.figure()
plt.title("Accuracy through replicas (MLP)")
plt.plot(acc.T[0]*100, label="Training")
plt.plot(acc.T[1]*100, label="Test")
plt.xlabel("Replica")
plt.ylabel("Accuracy")
plt.legend()

std = np.std(adrop, axis=0)*100
mean = np.mean(adrop, axis=0)*100
plt.figure()
plt.title("MLTSA - MLP")
plt.plot(mean)
plt.fill_between(np.arange(len(std)), y1=(mean+std), y2=(mean-std))
plt.ylabel("Accuracy")
plt.xlabel("Feature (CV)")

plt.figure()
plt.title("Feature Permutation Importances - MLP")
plt.plot(np.mean(permut, axis=0))

# %%
from MLTSA_sklearn.MLTSA_sk import MLTSA_Plot

#We simply get the plot with this
MLTSA_Plot(adrop, oneD_dataset, pots, errorbar=False)

MLTSA_Plot(np.array(permut)/100, oneD_dataset, pots, errorbar=False)

# %%
from MLTSA_sklearn.models import SKL_Train
from sklearn.ensemble import GradientBoostingClassifier
from MLTSA_sklearn.MLTSA_sk import MLTSA
from sklearn.inspection import permutation_importance

#For loop for MLTSA and Permutation on GBDT

replicas = 100

results_GB = {}
results_GB["MLTSA"] = []
results_GB["Imp"] = []
results_GB["Perm"] = []
results_GB["NN"] = []
results_GB["acc"] = []

for R in range(replicas):

    GBDT = GradientBoostingClassifier(random_state=0, verbose=False, n_estimators=500)
    trained_GBDT, train_acc, test_acc = SKL_Train(GBDT, X, Y)

    feat_perm = permutation_importance(trained_GBDT, X, Y, n_repeats=10, random_state=0)

    ADrop_train_avg = MLTSA(data[:,:,time_frame[0]:time_frame[1]], ans, trained_GBDT, drop_mode="Average")

    results_GB["MLTSA"].append(ADrop_train_avg)
    results_GB["Perm"].append(feat_perm)
    results_GB["NN"].append(trained_GBDT)
    results_GB["Imp"].append(trained_GBDT.feature_importances_)
    results_GB["acc"].append([train_acc, test_acc])
# Out:
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.93644332885742 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  47.07109189033508 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.42434239387512 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.56825304031372 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.79811191558838 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.67404389381409 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.56925320625305 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.490302085876465 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.912867069244385 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  47.10785722732544 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  47.379754066467285 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.62421894073486 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.69317650794983 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.4783091545105 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.76013469696045 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.39835858345032 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.41934585571289 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.49432635307312 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.33239960670471 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.368377923965454 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.60623025894165 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.522281646728516 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.600234270095825 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.464317083358765 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.80879592895508 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.34139347076416 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.33387875556946 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.447328090667725 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.298420906066895 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.39735960960388 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.38136911392212 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.81909894943237 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.53031921386719 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.33539652824402 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.50229454040527 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  47.086934089660645 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.367377042770386 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.334397077560425 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.48230504989624 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.520283222198486 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.682183504104614 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.4103524684906 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.33639669418335 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.398359537124634 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.358383893966675 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.32040619850159 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.30841422080994 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.495298862457275 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.33439898490906 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.508291482925415 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.56725525856018 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.73115396499634 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.39635968208313 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.32347917556763 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.198485374450684 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.53327536582947 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.60922861099243 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.76972198486328 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.37637209892273 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.97925066947937 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.35238718986511 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.65320110321045 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.57724857330322 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.816100120544434 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.40135669708252 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.37437200546265 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.481308937072754 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.758136510849 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.31341052055359 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.27243685722351 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.47228789329529 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.4313383102417 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.26144289970398 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.449326515197754 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.40835165977478 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.727155685424805 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.5012948513031 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.350393533706665 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.331403493881226 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.46532130241394 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.37337398529053 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.267438888549805 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.35238766670227 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.33117699623108 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.51828479766846 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.33040165901184 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.33139991760254 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.28742814064026 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.48730421066284 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.32040739059448 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.35338640213013 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.44832754135132 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.29642152786255 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.473313093185425 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.482306241989136 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.358384132385254 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.576247692108154 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.386367082595825 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.4213433265686 seconds
# Accuracy on Train is 100.0
# Accuracy on Test set is 99.86666666666667
# Trained in  46.33739709854126 seconds
# 100it [00:09, 10.50it/s]
# 100it [00:09, 10.52it/s]
# 100it [00:09, 10.55it/s]
# 100it [00:09, 10.42it/s]
# 100it [00:09, 10.38it/s]
# 100it [00:09, 10.44it/s]
# 100it [00:09, 10.55it/s]
# 100it [00:09, 10.61it/s]
# 100it [00:09, 10.61it/s]
# 100it [00:09, 10.59it/s]
# 100it [00:09, 10.59it/s]
# 100it [00:09, 10.59it/s]
# 100it [00:09, 10.45it/s]
# 100it [00:09, 10.71it/s]
# 100it [00:09, 10.67it/s]
# 100it [00:09, 10.76it/s]
# 100it [00:09, 10.68it/s]
# 100it [00:09, 10.56it/s]
# 100it [00:09, 10.57it/s]
# 100it [00:09, 10.64it/s]
# 100it [00:09, 10.59it/s]
# 100it [00:09, 10.70it/s]
# 100it [00:09, 10.65it/s]
# 100it [00:09, 10.56it/s]
# 100it [00:09, 10.51it/s]
# 100it [00:09, 10.50it/s]
# 100it [00:09, 10.75it/s]
# 100it [00:09, 10.65it/s]
# 100it [00:09, 10.64it/s]
# 100it [00:09, 10.69it/s]
# 100it [00:10,  9.84it/s]
# 100it [00:09, 10.74it/s]
# 100it [00:09, 10.70it/s]
# 100it [00:09, 10.42it/s]
# 100it [00:09, 10.23it/s]
# 100it [00:09, 10.57it/s]
# 100it [00:09, 10.62it/s]
# 100it [00:09, 10.66it/s]
# 100it [00:09, 10.73it/s]
# 100it [00:09, 10.33it/s]
# 100it [00:09, 10.57it/s]
# 100it [00:09, 10.62it/s]
# 100it [00:09, 10.70it/s]
# 100it [00:09, 10.66it/s]
# 100it [00:09, 10.66it/s]
# 100it [00:09, 10.64it/s]
# 100it [00:09, 10.52it/s]
# 100it [00:09, 10.51it/s]
# 100it [00:09, 10.66it/s]
# 100it [00:09, 10.69it/s]
# 100it [00:09, 10.69it/s]
# 100it [00:09, 10.61it/s]
# 100it [00:09, 10.74it/s]
# 100it [00:09, 10.65it/s]
# 100it [00:09, 10.74it/s]
# 100it [00:09, 10.75it/s]
# 100it [00:09, 10.80it/s]
# 100it [00:09, 10.81it/s]
# 100it [00:09, 10.74it/s]
# 100it [00:09, 10.70it/s]
# 100it [00:09, 10.60it/s]
# 100it [00:09, 10.66it/s]
# 100it [00:09, 10.71it/s]
# 100it [00:09, 10.75it/s]
# 100it [00:09, 10.72it/s]
# 100it [00:09, 10.68it/s]
# 100it [00:09, 10.59it/s]
# 100it [00:09, 10.55it/s]
# 100it [00:09, 10.64it/s]
# 100it [00:09, 10.51it/s]
# 100it [00:09, 10.40it/s]
# 100it [00:09, 10.44it/s]
# 100it [00:09, 10.51it/s]
# 100it [00:09, 10.34it/s]
# 100it [00:09, 10.69it/s]
# 100it [00:09, 10.52it/s]
# 100it [00:09, 10.43it/s]
# 100it [00:09, 10.53it/s]
# 100it [00:09, 10.47it/s]
# 100it [00:09, 10.59it/s]
# 100it [00:09, 10.71it/s]
# 100it [00:09, 10.61it/s]
# 100it [00:09, 10.44it/s]
# 100it [00:09, 10.64it/s]
# 100it [00:09, 10.59it/s]
# 100it [00:09, 10.71it/s]
# 100it [00:09, 10.71it/s]
# 100it [00:09, 10.71it/s]
# 100it [00:09, 10.71it/s]
# 100it [00:09, 10.63it/s]
# 100it [00:09, 10.52it/s]
# 100it [00:09, 10.57it/s]
# 100it [00:09, 10.49it/s]
# 100it [00:09, 10.63it/s]
# 100it [00:09, 10.59it/s]
# 100it [00:09, 10.54it/s]
# 100it [00:09, 10.67it/s]
# 100it [00:09, 10.64it/s]
# 100it [00:09, 10.48it/s]
# 100it [00:09, 10.71it/s]

# %%
acc = np.array(results_GB["acc"])
adrop = np.array(results_GB["MLTSA"])
permut = np.array(results_GB["Perm"])
permut = [x.importances_mean for x in permut]
imp = np.array(results_GB["Imp"])

plt.figure()
plt.title("Accuracy through replicas (GBDT)")
plt.plot(acc.T[0]*100, label="Training")
plt.plot(acc.T[1]*100, label="Test")
plt.xlabel("Replica")
plt.ylabel("Accuracy")
plt.legend()

std = np.std(adrop, axis=0)*100
mean = np.mean(adrop, axis=0)*100
plt.figure()
plt.title("MLTSA - GBDT")
plt.plot(mean)
plt.fill_between(np.arange(len(std)), y1=(mean+std), y2=(mean-std))
plt.ylabel("Accuracy")
plt.xlabel("Feature (CV)")

plt.figure()
plt.title("Feature Permutation Importances - GBDT")
plt.plot(np.mean(permut, axis=0))
plt.ylabel("Mean Importance")
plt.xlabel("Feature (CV)")

plt.figure()
plt.title("Feature Importances - GBDT")
plt.plot(np.mean(imp, axis=0))
plt.ylabel("Gini Importance")
plt.xlabel("Feature (CV)")
# Out:
# Text(0.5, 0, 'Feature (CV)')

# %%
MLTSA_Plot(adrop, oneD_dataset, pots, errorbar=False)

MLTSA_Plot(np.array(permut)/100, oneD_dataset, pots, errorbar=False)

MLTSA_Plot(imp/100, oneD_dataset, pots, errorbar=False)

# %%
# Out:
# array([-3.00000000e-04, -4.66666667e-04, -5.33333333e-04,  3.66666667e-04,
#        -1.66666667e-04,  0.00000000e+00, -8.66666667e-04, -2.00000000e-04,
#        -7.66666667e-04, -5.33333333e-04, -3.33333333e-04, -7.33333333e-04,
#        -3.33333333e-05, -5.00000000e-04,  3.33333333e-05, -2.00000000e-04,
#        -8.00000000e-04, -2.00000000e-04,  0.00000000e+00, -1.26666667e-03,
#         1.76666667e-03,  2.00000000e-04,  1.66666667e-04,  0.00000000e+00,
#         0.00000000e+00,  2.00000000e-04, -8.66666667e-04,  1.33333333e-04,
#        -6.66666667e-05, -1.03333333e-03, -7.00000000e-04,  3.33333333e-05,
#        -6.33333333e-04, -4.33333333e-04,  1.33333333e-04, -3.00000000e-04,
#        -3.33333333e-04, -5.00000000e-04,  7.10000000e-03, -4.66666667e-04,
#         2.00000000e-04, -3.33333333e-05, -1.16666667e-03,  3.33333333e-05,
#        -4.00000000e-04, -6.66666667e-04, -1.20000000e-03,  3.33333333e-05,
#        -2.00000000e-04, -9.00000000e-04,  3.66666667e-04,  2.33333333e-04,
#        -3.00000000e-04, -1.00000000e-04, -1.30000000e-03, -3.00000000e-04,
#        -9.00000000e-04, -3.33333333e-04, -8.33333333e-04, -6.00000000e-04,
#        -2.33333333e-04, -2.66666667e-04, -2.33333333e-04, -2.66666667e-04,
#        -1.06666667e-03,  1.33333333e-04, -5.66666667e-04,  2.65666667e-02,
#        -2.33333333e-04,  1.11022302e-17, -2.00000000e-04, -3.66666667e-04,
#         2.63333333e-03, -4.66666667e-04, -1.00000000e-04, -4.00000000e-04,
#         1.33333333e-04, -8.66666667e-04, -1.50000000e-03,  3.66666667e-04,
#         2.59000000e-02, -1.33333333e-04, -9.33333333e-04,  5.00000000e-04,
#         6.66666667e-05,  1.33333333e-04, -2.33333333e-04,  2.66666667e-04,
#         0.00000000e+00, -7.00000000e-04, -3.66666667e-04, -1.66666667e-04,
#         3.33333333e-05,  0.00000000e+00, -7.33333333e-04, -1.00000000e-04,
#         6.66666667e-05, -3.00000000e-04, -3.66666667e-04,  8.83333333e-03,
#         1.33333333e-04,  6.66666667e-05, -1.33333333e-04, -6.66666667e-04,
#         3.33333333e-05, -7.33333333e-04, -5.66666667e-04, -5.33333333e-04,
#        -6.33333333e-04, -6.33333333e-04, -6.33333333e-04, -1.66666667e-04,
#        -1.33333333e-04, -1.43333333e-03, -5.66666667e-04, -1.33333333e-04,
#        -1.00000000e-04, -6.33333333e-04, -9.00000000e-04, -2.00000000e-04,
#        -4.00000000e-04, -5.66666667e-04, -3.33333333e-04, -9.00000000e-04,
#         3.20000000e-03, -4.33333333e-04, -3.00000000e-04, -6.66666667e-04,
#        -1.23333333e-03, -3.00000000e-04, -1.03333333e-03,  1.83333333e-03,
#        -2.66666667e-04, -6.33333333e-04, -4.66666667e-04, -6.00000000e-04,
#        -2.66666667e-04,  3.93333333e-03, -8.00000000e-04,  0.00000000e+00,
#         5.33333333e-03, -1.66666667e-04, -8.66666667e-04,  0.00000000e+00,
#        -6.66666667e-05, -2.33333333e-04, -1.66666667e-04,  1.33333333e-04,
#        -8.00000000e-04, -2.00000000e-04,  2.15333333e-02, -5.66666667e-04,
#        -1.03333333e-03, -1.66666667e-04,  2.33333333e-04, -2.03333333e-03,
#        -1.10000000e-03, -8.00000000e-04, -3.33333333e-04,  6.66666667e-05,
#        -3.33333333e-04, -1.66666667e-04, -3.33333333e-05, -3.00000000e-04,
#         3.38333333e-02,  9.00000000e-04, -1.56666667e-03, -1.23333333e-03,
#        -4.33333333e-04,  1.27666667e-02, -5.33333333e-04, -6.66666667e-05,
#        -1.66666667e-04, -7.33333333e-04, -2.66666667e-04, -3.33333333e-04,
#        -1.00000000e-04,  6.33333333e-04, -2.00000000e-04, -2.00000000e-04])

# %%
# Out:
# Text(0.5, 0, '$\\alpha y^{*} + (1-\\alpha)y$')

# %%
# Out:
# Shape of X is: (3000, 180)
# Shape of Y is: (3000,)
# X and Y have the same length: True

# %%
# Out:
# Accuracy on Train is 91.2
# Accuracy on Test set is 91.33333333333333
# Trained in  6.1915647983551025 seconds

# %%
# Out:
# Generating dataset
# Running Simulations: 100%|#############################################################| 25/25 [00:06<00:00,  3.88it/s]
# Getting simulation labels for the generated data
# Classifying Simulation Outcomes: 100%|#########################################################| 25/25 [00:00<?, ?it/s]
# Validation Accuracy is 89.06666666666668

# %%
from MLTSA_sklearn.MLTSA_sk import MLTSA

#We Call the method on the data, labels and trained NN.
ADrop_train_avg = MLTSA(data[:,:,time_frame[0]:time_frame[1]], ans, trained_NN, drop_mode="Average")
# Out:
# 100it [00:07, 13.90it/s]

# %%
plt.figure(figsize=(10,4))
plt.plot(ADrop_train_avg*100, label="Training Accuracy Drop", color="C0")
plt.legend()
plt.xlabel("# Feature")
plt.ylabel("Accuracy (%)")
plt.ylim()
# Out:
# (90.62833333333333, 91.47166666666669)

# %%
from MLTSA_sklearn.MLTSA_sk import MLTSA_Plot

#We simply get the plot with this
MLTSA_Plot([ADrop_train_avg], oneD_dataset, pots, errorbar=False)
# Out:
# C:\Users\k1802891\Anaconda3\lib\site-packages\numpy\core\_methods.py:263: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims, where=where)
# C:\Users\k1802891\Anaconda3\lib\site-packages\numpy\core\_methods.py:252: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\k1802891\Anaconda3\lib\site-packages\MLTSA_sklearn\MLTSA_sk.py:100: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(dat, "-o", color="black", marker="s")

# %% [markdown]
# This plots shows the accuracy drop for every single feature after swapping them with their global mean accross simulations. The features highlighted with a coloured cross are correlated features having red as the most correlated (100%) and blue as the least (0%).
