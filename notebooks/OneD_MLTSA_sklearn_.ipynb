# %% [markdown]
# # Basic 1D potential example using Scikit-Learn
#
# ###### *Note that this Jupyter Notebook requires you to have the MLTSA package installed.

# %%
"""First we import our dataset examples"""
from MLTSA_datasets.OneD_pot.OneD_pot_data import potentials #We import the potentials class which will define them.
from MLTSA_datasets.OneD_pot.OneD_pot_data import dataset #We import the dataset class which will hold our potentials.
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-208debe10eb4> in <module>
#       1 """First we import our dataset examples"""
# ----> 2 from MLTSA_datasets.OneD_pot.OneD_pot_data import potentials #We import the potentials class which will define them.
#       3 from MLTSA_datasets.OneD_pot.OneD_pot_data import dataset #We import the dataset class which will hold our potentials.
#       4 import matplotlib.pyplot as plt
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'MLTSA_datasets'

# %%
#This sets the potentials, don't re-run
total_n_pots = 25
n_DW = 5
relevant_DW_n = 2
#After defining the desired parameters we define the potentials accordingly
pots = potentials(total_n_pots, n_DW, relevant_DW_n)
# This creates the first dataset of data.
# It creates the mixing coefficients don't re-run
n_features = 180
degree_of_mixing = 2
#We specified the number of features wanted and how much they will mix
oneD_dataset = dataset(pots, n_features, degree_of_mixing)
# Out:
# Defining Potentials: 100%|##########| 25/25 [00:00<00:00, 1389.80it/s]

# %% [markdown]
# We have defined the potentials which we will use to generate data and  we created the dataset which we will use throughout the example
#
# Now we can generate data easily for our example. We will start by generating the data straight from the potentials before adding more complexity to the system

# %%
n_sims = 100
n_steps = 500
simple_data = pots.generate_data(n_sims, n_steps)
# Out:
# Running Simulations: 100%|##########| 100/100 [00:54<00:00,  1.84it/s]
# Classifying Simulation Outcomes: 100%|##########| 100/100 [00:00<00:00, 99911.96it/s]
# Generating dataset
# Getting simulation labels for the generated data

# %% [markdown]
# We generated 100 simulations with 500 steps each. Let's see how the data looks like on these simulations, we will plot the relevant DW potential to see that it ends up in two different values after the given number of steps.

# %%
""" We have succesfully created test data for our MLTSA to analyze """
plt.plot(simple_data[0][:,pots.relevant_id,:].T, color="r", label="DW potential", alpha=0.1)
plt.plot(simple_data[0][:,-1,:].T, color="b", label="SW potential", alpha=0.1)
handles, labels = plt.gca().get_legend_handles_labels()
temp = {k:v for k,v in zip(labels, handles)}
plt.legend(temp.values(), temp.keys(), loc='best');
plt.xlabel("Simulation Steps")
plt.ylabel("Reaction Coordinate")
# Out:
# Text(0, 0.5, 'Reaction Coordinate')

# %% [markdown]
# Now we will generate complex data for our ML model to learn and we will visualize it as previously done. For this we simply call the generate_linear method on the dataset class which will return an array with the simulation data and the labels for each one of them.

# %%
n_simulations = 100
n_steps = 500
data, ans = oneD_dataset.generate_linear(n_simulations, n_steps)
# Out:
# Running Simulations: 100%|##########| 100/100 [00:50<00:00,  1.97it/s]
# Classifying Simulation Outcomes: 100%|##########| 100/100 [00:00<?, ?it/s]
# Generating dataset
# Getting simulation labels for the generated data

# %%
#We proceed to plot the values
fig, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].plot(data[0,0,:], color="r", label="Sim 1, feature 1")
axs[1].plot(data[0,1,:], color="r", label="Sim 1, feature 2")
axs[0].plot(data[1,0,:], color="b", label="Sim 2, feature 1")
axs[1].plot(data[1,1,:], color="b", label="Sim 2, feature 2")
axs[0].legend()
axs[1].legend()
axs[1].set_xlabel("Simulation Steps")
axs[1].set_ylabel("Reaction Coordinate")
axs[0].set_xlabel("Simulation Steps")
axs[0].set_ylabel("Reaction Coordinate")
# Out:
# Text(0, 0.5, 'Reaction Coordinate')

# %% [markdown]
# We see now that the features we plotted are noisy, when we do generate_linear we mixed the original simulation data for each potential (both SW and DW) with different mixing coefficient. We can even trace back which features have been mixed with our "known" relevant DW potential and see how it looks now.

# %%
relevant_dists = np.concatenate((np.where(pots.relevant_id == np.array(oneD_dataset.combinations).T[1])[0],
                          np.where(pots.relevant_id == np.array(oneD_dataset.combinations).T[0])[0]))
print("Features combined with the relevant DW are:", list(relevant_dists))
# Out:
# Features combined with the relevant DW are: [23, 41, 89, 123, 8, 10, 59, 72, 82, 91, 97, 116, 128, 165]

# %%
for feat in relevant_dists:
    print("Feature", feat,"- Potentials involved:",list(oneD_dataset.combinations[feat]))
    summ = np.array(oneD_dataset.mixing_coefs).T[feat][1] + np.array(oneD_dataset.mixing_coefs).T[feat][0]
    print("Pot1:", np.around(100 *np.array(oneD_dataset.mixing_coefs).T[feat][0]/summ, decimals=2), "%")
    print("Pot2:", np.around(100 *np.array(oneD_dataset.mixing_coefs).T[feat][1]/summ, decimals=2), "%")
# Out:
# Feature 23 - Potentials involved: [2, 6]
# Pot1: 17.14 %
# Pot2: 82.86 %
# Feature 41 - Potentials involved: [1, 6]
# Pot1: 86.4 %
# Pot2: 13.6 %
# Feature 89 - Potentials involved: [3, 6]
# Pot1: 75.12 %
# Pot2: 24.88 %
# Feature 123 - Potentials involved: [4, 6]
# Pot1: 45.25 %
# Pot2: 54.75 %
# Feature 8 - Potentials involved: [6, 10]
# Pot1: 95.65 %
# Pot2: 4.35 %
# Feature 10 - Potentials involved: [6, 20]
# Pot1: 76.63 %
# Pot2: 23.37 %
# Feature 59 - Potentials involved: [6, 18]
# Pot1: 75.74 %
# Pot2: 24.26 %
# Feature 72 - Potentials involved: [6, 21]
# Pot1: 59.97 %
# Pot2: 40.03 %
# Feature 82 - Potentials involved: [6, 19]
# Pot1: 56.6 %
# Pot2: 43.4 %
# Feature 91 - Potentials involved: [6, 9]
# Pot1: 29.36 %
# Pot2: 70.64 %
# Feature 97 - Potentials involved: [6, 15]
# Pot1: 31.05 %
# Pot2: 68.95 %
# Feature 116 - Potentials involved: [6, 22]
# Pot1: 12.02 %
# Pot2: 87.98 %
# Feature 128 - Potentials involved: [6, 12]
# Pot1: 41.91 %
# Pot2: 58.09 %
# Feature 165 - Potentials involved: [6, 16]
# Pot1: 66.19 %
# Pot2: 33.81 %

# %% [markdown]
# Since we got our simulations classified we can see how the different features look like for each feature, you can try changing the number to see other features:

# %%
#We can choose which feature to plot here
feature_to_plot = 84
plt.figure(figsize=(5,7))
for dat, answer in zip(data[:,feature_to_plot,:], ans):
    if answer == "IN":
        plt.plot(list(reversed(dat)), np.arange(0, len(dat)), color="blue", alpha=0.1)
    elif answer == "OUT":
        plt.plot(list(reversed(dat)), np.arange(0, len(dat)), color="r", alpha=0.1)
plt.ylabel("time (steps)")
plt.xlabel(r'$\alpha y^{*} + (1-\alpha)y$')
# Out:
# Text(0.5, 0, '$\\alpha y^{*} + (1-\\alpha)y$')

# %% [markdown]
# Now that we made sure our data is scrambled and it is ready to work with, we will simply format it according to what our ML model needs.
#
# Since we are using an MLP with the number of features as inputs we need to concatenate the frames of the different simulations one after the other in order to get our X. This input data (X) will have the shape of (n_frames, n_features). To get the target values (Y) to fit to, we will have to get the outcome labels (IN/OUT) from the simulations for each corresponding frame,  which will result in a Y with shape (n_frames).
#
# For this task we will use the PrepareData() method on our 1D dataset, this will give us the input data (X) and target values (Y) in an appropriate format to use. Additionally the method allows one to only use a particular range of data instead of the whole length which would be too easy for the ML approach to predict.

# %%
time_frame = [30, 60]

X, Y = oneD_dataset.PrepareData(data, ans, time_frame, mode="Normal")

print("Shape of X is:", X.shape)
print("Shape of Y is:", Y.shape)
print("X and Y have the same length:", len(X) == len(Y))
# Out:
# Shape of X is: (3000, 180)
# Shape of Y is: (3000,)
# X and Y have the same length: True

# %% [markdown]
# Our simulation data is ready to be used now, so we will import the necessary functions for applying our MLTSA. First we need the ML algorithm and the MLTSA methods.
#
# This module has full implementation with Scikit-Learn models so we can directly import them.

# %%
from MLTSA_sklearn.models import SKL_Train
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# Next step is to train the model on data, we use the SKL_Train() function which needs the classifier, X and Y data to fit.
# This classifier can be any within the SKlearn suite that uses the .fit() method and the .predict() method.
#
# We can simply call an Multi-Layer Perceptron from SK-learn and tune it as we want. In this case we will set the verbose to True and put a maximum number of iterations so it does not train for too long.
# Remember you can do this by hand but we just provided some wrappers to make it easier.

# %%
NN = MLPClassifier(random_state=1, verbose=True, max_iter=500) # You can set the verbose to false for less prints.

trained_NN, train_acc, test_acc = SKL_Train(NN, X, Y)
# Out:
# Iteration 1, loss = 0.69891418
# Iteration 2, loss = 0.68914809
# Iteration 3, loss = 0.68915530
# Iteration 4, loss = 0.68913829
# Iteration 5, loss = 0.68451974
# Iteration 6, loss = 0.69144646
# Iteration 7, loss = 0.68587893
# Iteration 8, loss = 0.68578060
# Iteration 9, loss = 0.70158446
# Iteration 10, loss = 0.68768574
# Iteration 11, loss = 0.68181319
# Iteration 12, loss = 0.68090787
# Iteration 13, loss = 0.68298205
# Iteration 14, loss = 0.68263269
# Iteration 15, loss = 0.67942260
# Iteration 16, loss = 0.68221769
# Iteration 17, loss = 0.68168060
# Iteration 18, loss = 0.67771930
# Iteration 19, loss = 0.67754725
# Iteration 20, loss = 0.67696699
# Iteration 21, loss = 0.68072399
# Iteration 22, loss = 0.67601307
# Iteration 23, loss = 0.68377710
# Iteration 24, loss = 0.68144009
# Iteration 25, loss = 0.68436180
# Iteration 26, loss = 0.67956541
# Iteration 27, loss = 0.67157256
# Iteration 28, loss = 0.67125545
# Iteration 29, loss = 0.67080449
# Iteration 30, loss = 0.67109346
# Iteration 31, loss = 0.67232673
# Iteration 32, loss = 0.67426568
# Iteration 33, loss = 0.66788585
# Iteration 34, loss = 0.67149170
# Iteration 35, loss = 0.66581467
# Iteration 36, loss = 0.66817976
# Iteration 37, loss = 0.66959459
# Iteration 38, loss = 0.66461848
# Iteration 39, loss = 0.66697452
# Iteration 40, loss = 0.66836559
# Iteration 41, loss = 0.67696363
# Iteration 42, loss = 0.66173431
# Iteration 43, loss = 0.66745904
# Iteration 44, loss = 0.66062675
# Iteration 45, loss = 0.66370770
# Iteration 46, loss = 0.65554384
# Iteration 47, loss = 0.66057888
# Iteration 48, loss = 0.65439642
# Iteration 49, loss = 0.65853337
# Iteration 50, loss = 0.65176085
# Iteration 51, loss = 0.65206468
# Iteration 52, loss = 0.65232964
# Iteration 53, loss = 0.65216535
# Iteration 54, loss = 0.65087361
# Iteration 55, loss = 0.64655200
# Iteration 56, loss = 0.65756323
# Iteration 57, loss = 0.67616846
# Iteration 58, loss = 0.65820525
# Iteration 59, loss = 0.64421247
# Iteration 60, loss = 0.64513291
# Iteration 61, loss = 0.63934462
# Iteration 62, loss = 0.63804967
# Iteration 63, loss = 0.64681058
# Iteration 64, loss = 0.63674520
# Iteration 65, loss = 0.63163471
# Iteration 66, loss = 0.63562338
# Iteration 67, loss = 0.64066300
# Iteration 68, loss = 0.63530006
# Iteration 69, loss = 0.62727395
# Iteration 70, loss = 0.62589833
# Iteration 71, loss = 0.63259250
# Iteration 72, loss = 0.62427122
# Iteration 73, loss = 0.62259871
# Iteration 74, loss = 0.62057564
# Iteration 75, loss = 0.62951879
# Iteration 76, loss = 0.62099418
# Iteration 77, loss = 0.61912405
# Iteration 78, loss = 0.61451357
# Iteration 79, loss = 0.60775109
# Iteration 80, loss = 0.60759881
# Iteration 81, loss = 0.62578781
# Iteration 82, loss = 0.60175747
# Iteration 83, loss = 0.59939145
# Iteration 84, loss = 0.59747453
# Iteration 85, loss = 0.60137733
# Iteration 86, loss = 0.61922644
# Iteration 87, loss = 0.59694312
# Iteration 88, loss = 0.58963493
# Iteration 89, loss = 0.59082837
# Iteration 90, loss = 0.58571964
# Iteration 91, loss = 0.60342858
# Iteration 92, loss = 0.61554328
# Iteration 93, loss = 0.59298474
# Iteration 94, loss = 0.58408856
# Iteration 95, loss = 0.58082795
# Iteration 96, loss = 0.57254658
# Iteration 97, loss = 0.57222254
# Iteration 98, loss = 0.57323650
# Iteration 99, loss = 0.59326965
# Iteration 100, loss = 0.56956410
# Iteration 101, loss = 0.57195587
# Iteration 102, loss = 0.56109024
# Iteration 103, loss = 0.56413058
# Iteration 104, loss = 0.56058882
# Iteration 105, loss = 0.55351800
# Iteration 106, loss = 0.55372111
# Iteration 107, loss = 0.56063188
# Iteration 108, loss = 0.55899077
# Iteration 109, loss = 0.55417600
# Iteration 110, loss = 0.55143103
# Iteration 111, loss = 0.54795423
# Iteration 112, loss = 0.53847389
# Iteration 113, loss = 0.53506064
# Iteration 114, loss = 0.53148868
# Iteration 115, loss = 0.53791369
# Iteration 116, loss = 0.52750430
# Iteration 117, loss = 0.52376501
# Iteration 118, loss = 0.52446865
# Iteration 119, loss = 0.52927952
# Iteration 120, loss = 0.53746822
# Iteration 121, loss = 0.52137695
# Iteration 122, loss = 0.51601642
# Iteration 123, loss = 0.52229222
# Iteration 124, loss = 0.51257817
# Iteration 125, loss = 0.52353590
# Iteration 126, loss = 0.52237523
# Iteration 127, loss = 0.50872474
# Iteration 128, loss = 0.51128905
# Iteration 129, loss = 0.50294153
# Iteration 130, loss = 0.49540007
# Iteration 131, loss = 0.49941649
# Iteration 132, loss = 0.49108096
# Iteration 133, loss = 0.49913597
# Iteration 134, loss = 0.49007046
# Iteration 135, loss = 0.48965175
# Iteration 136, loss = 0.49935659
# Iteration 137, loss = 0.49988560
# Iteration 138, loss = 0.48660773
# Iteration 139, loss = 0.47615450
# Iteration 140, loss = 0.48145786
# Iteration 141, loss = 0.47018597
# Iteration 142, loss = 0.47641401
# Iteration 143, loss = 0.48327630
# Iteration 144, loss = 0.47751824
# Iteration 145, loss = 0.48516756
# Iteration 146, loss = 0.47232528
# Iteration 147, loss = 0.47626742
# Iteration 148, loss = 0.46585638
# Iteration 149, loss = 0.47037114
# Iteration 150, loss = 0.45442973
# Iteration 151, loss = 0.46195776
# Iteration 152, loss = 0.45238426
# Iteration 153, loss = 0.44793100
# Iteration 154, loss = 0.45083151
# Iteration 155, loss = 0.46648562
# Iteration 156, loss = 0.45116258
# Iteration 157, loss = 0.44270100
# Iteration 158, loss = 0.44066540
# Iteration 159, loss = 0.44436803
# Iteration 160, loss = 0.44279620
# Iteration 161, loss = 0.45447193
# Iteration 162, loss = 0.44513329
# Iteration 163, loss = 0.43032579
# Iteration 164, loss = 0.45115382
# Iteration 165, loss = 0.43002497
# Iteration 166, loss = 0.43722532
# Iteration 167, loss = 0.44830855
# Iteration 168, loss = 0.42692424
# Iteration 169, loss = 0.42201154
# Iteration 170, loss = 0.41940082
# Iteration 171, loss = 0.43326137
# Iteration 172, loss = 0.45114519
# Iteration 173, loss = 0.42050900
# Iteration 174, loss = 0.42918903
# Iteration 175, loss = 0.40765458
# Iteration 176, loss = 0.41114160
# Iteration 177, loss = 0.42309480
# Iteration 178, loss = 0.41853528
# Iteration 179, loss = 0.40992818
# Iteration 180, loss = 0.40178019
# Iteration 181, loss = 0.40571975
# Iteration 182, loss = 0.40771554
# Iteration 183, loss = 0.39650897
# Iteration 184, loss = 0.39489063
# Iteration 185, loss = 0.39326672
# Iteration 186, loss = 0.39193629
# Iteration 187, loss = 0.39230805
# Iteration 188, loss = 0.38961490
# Iteration 189, loss = 0.39731616
# Iteration 190, loss = 0.39770005
# Iteration 191, loss = 0.39414563
# Iteration 192, loss = 0.40245981
# Iteration 193, loss = 0.39326430
# Iteration 194, loss = 0.39070797
# Iteration 195, loss = 0.37965869
# Iteration 196, loss = 0.37865849
# Iteration 197, loss = 0.38639793
# Iteration 198, loss = 0.38419908
# Iteration 199, loss = 0.38890782
# Iteration 200, loss = 0.38526610
# Iteration 201, loss = 0.37889578
# Iteration 202, loss = 0.38126959
# Iteration 203, loss = 0.36949161
# Iteration 204, loss = 0.38655545
# Iteration 205, loss = 0.38432375
# Iteration 206, loss = 0.37647064
# Iteration 207, loss = 0.36783251
# Iteration 208, loss = 0.37611847
# Iteration 209, loss = 0.36435258
# Iteration 210, loss = 0.35818669
# Iteration 211, loss = 0.35958629
# Iteration 212, loss = 0.36956668
# Iteration 213, loss = 0.35487288
# Iteration 214, loss = 0.35712420
# Iteration 215, loss = 0.35048206
# Iteration 216, loss = 0.35177498
# Iteration 217, loss = 0.34873501
# Iteration 218, loss = 0.34799541
# Iteration 219, loss = 0.35367044
# Iteration 220, loss = 0.35374120
# Iteration 221, loss = 0.34521444
# Iteration 222, loss = 0.34785192
# Iteration 223, loss = 0.35389948
# Iteration 224, loss = 0.34174976
# Iteration 225, loss = 0.34972128
# Iteration 226, loss = 0.34322849
# Iteration 227, loss = 0.34895586
# Iteration 228, loss = 0.33911280
# Iteration 229, loss = 0.33523048
# Iteration 230, loss = 0.33615805
# Iteration 231, loss = 0.33177566
# Iteration 232, loss = 0.33917293
# Iteration 233, loss = 0.33429219
# Iteration 234, loss = 0.33265029
# Iteration 235, loss = 0.35092085
# Iteration 236, loss = 0.35061332
# Iteration 237, loss = 0.33370313
# Iteration 238, loss = 0.32645992
# Iteration 239, loss = 0.32170088
# Iteration 240, loss = 0.33873724
# Iteration 241, loss = 0.33193610
# Iteration 242, loss = 0.33013205
# Iteration 243, loss = 0.32147480
# Iteration 244, loss = 0.32042613
# Iteration 245, loss = 0.33417076
# Iteration 246, loss = 0.31724511
# Iteration 247, loss = 0.33265304
# Iteration 248, loss = 0.32052154
# Iteration 249, loss = 0.32204614
# Iteration 250, loss = 0.31524978
# Iteration 251, loss = 0.32810277
# Iteration 252, loss = 0.32239712
# Iteration 253, loss = 0.33076043
# Iteration 254, loss = 0.32045646
# Iteration 255, loss = 0.31588522
# Iteration 256, loss = 0.31336266
# Iteration 257, loss = 0.31052131
# Iteration 258, loss = 0.30366683
# Iteration 259, loss = 0.30969168
# Iteration 260, loss = 0.30393459
# Iteration 261, loss = 0.30583932
# Iteration 262, loss = 0.30386398
# Iteration 263, loss = 0.30902407
# Iteration 264, loss = 0.31607918
# Iteration 265, loss = 0.29972236
# Iteration 266, loss = 0.30299415
# Iteration 267, loss = 0.30172854
# Iteration 268, loss = 0.31350092
# Iteration 269, loss = 0.29459912
# Iteration 270, loss = 0.30172144
# Iteration 271, loss = 0.30216701
# Iteration 272, loss = 0.29356489
# Iteration 273, loss = 0.30849831
# Iteration 274, loss = 0.29400693
# Iteration 275, loss = 0.29063799
# Iteration 276, loss = 0.31074833
# Iteration 277, loss = 0.29641233
# Iteration 278, loss = 0.28445062
# Iteration 279, loss = 0.28351081
# Iteration 280, loss = 0.28785337
# Iteration 281, loss = 0.28782446
# Iteration 282, loss = 0.29360446
# Iteration 283, loss = 0.28417618
# Iteration 284, loss = 0.28351943
# Iteration 285, loss = 0.27982983
# Iteration 286, loss = 0.28528800
# Iteration 287, loss = 0.27956373
# Iteration 288, loss = 0.27588420
# Iteration 289, loss = 0.28849742
# Iteration 290, loss = 0.27941799
# Iteration 291, loss = 0.27553520
# Iteration 292, loss = 0.28748830
# Iteration 293, loss = 0.28142679
# Iteration 294, loss = 0.27884549
# Iteration 295, loss = 0.27171271
# Iteration 296, loss = 0.26969011
# Iteration 297, loss = 0.28991293
# Iteration 298, loss = 0.27817935
# Iteration 299, loss = 0.27961366
# Iteration 300, loss = 0.27600465
# Iteration 301, loss = 0.26905628
# Iteration 302, loss = 0.26605704
# Iteration 303, loss = 0.27784449
# Iteration 304, loss = 0.28602279
# Iteration 305, loss = 0.28130388
# Iteration 306, loss = 0.26388372
# Iteration 307, loss = 0.27765311
# Iteration 308, loss = 0.27691311
# Iteration 309, loss = 0.26687288
# Iteration 310, loss = 0.27569426
# Iteration 311, loss = 0.26333066
# Iteration 312, loss = 0.30101073
# Iteration 313, loss = 0.28009291
# Iteration 314, loss = 0.29274553
# Iteration 315, loss = 0.26790304
# Iteration 316, loss = 0.25840282
# Iteration 317, loss = 0.26157860
# Iteration 318, loss = 0.25875589
# Iteration 319, loss = 0.25331890
# Iteration 320, loss = 0.25672982
# Iteration 321, loss = 0.25288206
# Iteration 322, loss = 0.25444183
# Iteration 323, loss = 0.25820559
# Iteration 324, loss = 0.26656549
# Iteration 325, loss = 0.28240442
# Iteration 326, loss = 0.25364875
# Iteration 327, loss = 0.25140643
# Iteration 328, loss = 0.25236252
# Iteration 329, loss = 0.25152763
# Iteration 330, loss = 0.24720662
# Iteration 331, loss = 0.24884419
# Iteration 332, loss = 0.27631575
# Iteration 333, loss = 0.26991004
# Iteration 334, loss = 0.26424273
# Iteration 335, loss = 0.24883523
# Iteration 336, loss = 0.25285295
# Iteration 337, loss = 0.24775772
# Iteration 338, loss = 0.24287823
# Iteration 339, loss = 0.25366375
# Iteration 340, loss = 0.25366634
# Iteration 341, loss = 0.27315110
# Iteration 342, loss = 0.24902802
# Iteration 343, loss = 0.24108579
# Iteration 344, loss = 0.24751109
# Iteration 345, loss = 0.23955077
# Iteration 346, loss = 0.24057233
# Iteration 347, loss = 0.24158058
# Iteration 348, loss = 0.24259449
# Iteration 349, loss = 0.24613781
# Iteration 350, loss = 0.23643686
# Iteration 351, loss = 0.23507100
# Iteration 352, loss = 0.23641834
# Iteration 353, loss = 0.23607915
# Iteration 354, loss = 0.23299467
# Iteration 355, loss = 0.23861982
# Iteration 356, loss = 0.24685474
# Iteration 357, loss = 0.22965373
# Iteration 358, loss = 0.23089865
# Iteration 359, loss = 0.23542475
# Iteration 360, loss = 0.24503981
# Iteration 361, loss = 0.26664582
# Iteration 362, loss = 0.26183516
# Iteration 363, loss = 0.25727351
# Iteration 364, loss = 0.23719899
# Iteration 365, loss = 0.26410217
# Iteration 366, loss = 0.25275528
# Iteration 367, loss = 0.23471798
# Iteration 368, loss = 0.23157872
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Accuracy on Train is 92.84444444444443
# Accuracy on Test set is 93.46666666666667
# Trained in  12.410831928253174 seconds

# %% [markdown]
# If you used the default options from this notebook, you should have gotten around 96% accuracy on training and 95% on test without breaking a sweat.
#
# In case you have doubts about the accuracy, we can do a simple validation test generating new data from scratch.

# %%
""" Time for Validation with new simulations """

#Generate 25 additional simulations data
data_val, ans_val = oneD_dataset.generate_linear(25, 500)

#Prepare for trial
X_val, Y_val = oneD_dataset.PrepareData(data_val, ans_val, time_frame, mode="Normal")

#Predict the new simulations on the already trained NN
Y_pred = trained_NN.predict(X_val)
val_acc = Y_val == Y_pred
val_acc = np.mean(val_acc)

print("Validation Accuracy is", val_acc*100)
# Out:
# Running Simulations: 100%|##########| 25/25 [00:12<00:00,  2.00it/s]
# Classifying Simulation Outcomes: 100%|##########| 25/25 [00:00<?, ?it/s]
# Generating dataset
# Getting simulation labels for the generated data
# Validation Accuracy is 79.2

# %% [markdown]
# Once we are happy about the training on our ML model we can move onto trying to detect those correlated features.
#
# For this we simply call the MLTSA() function on the data and the trained model.

# %%
from MLTSA_sklearn.MLTSA_sk import MLTSA

#We Call the method on the data, labels and trained NN.
ADrop_train_avg = MLTSA(data[:,:,time_frame[0]:time_frame[1]], ans, trained_NN, drop_mode="Average")
# Out:
# 100it [00:13,  7.46it/s]
# 100it [00:10,  9.17it/s]

# %% [markdown]
# ADrop means accuracy drop which is what we usually look for when trying to find important distances.
#
# The easiest way to detect those is plotting the values obtained.

# %%
plt.figure(figsize=(10,4))
plt.plot(ADrop_train_avg*100, label="Training Accuracy Drop", color="C0")
plt.legend()
plt.xlabel("# Feature")
plt.ylabel("Accuracy (%)")
plt.ylim()
# Out:
# (91.65666666666665, 93.34333333333332)

# %% [markdown]
# Now for easier visualization, we included code to plot this to look like the original paper.
#
# This function will plot the MLTSA results in a manner which is easier to interpret and highlight the known to be correlated values to confirm the ML has detected them.

# %%
from MLTSA_sklearn.MLTSA_sk import MLTSA_Plot

#We simply get the plot with this
MLTSA_Plot([ADrop_train_avg], oneD_dataset, pots, errorbar=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:224: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:224: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)

# %% [markdown]
# This plots shows the accuracy drop for every single feature after swapping them with their global mean accross simulations. The features highlighted with a coloured cross are correlated features having red as the most correlated (100%) and blue as the least (0%).
