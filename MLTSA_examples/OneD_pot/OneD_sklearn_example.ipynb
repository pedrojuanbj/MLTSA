# %% [markdown]
# ## Basic 1D potential example using Scikit-Learn

# %%
from MLTSA_sklearn.models import SKL_Train
"""First we import our dataset examples"""
from OneD_pot_data import potentials
from OneD_pot_data import dataset
import matplotlib.pyplot as plt
import numpy as np

# %%
#This sets the potentials, don't re-run
total_n_pots = 25
n_DW = 5
relevant_DW_n = 2
#After defining the desired parameters we define the potentials accordingly
pots = potentials(total_n_pots, n_DW, relevant_DW_n)
# This creates the first dataset of data.
# It creates the mixing coefficients don't re-run
n_features = 180
degree_of_mixing = 2
#We specified the number of features wanted and how much they will mix
oneD_dataset = dataset(pots, n_features, degree_of_mixing)
# Out:
# Defining Potentials: 100%|##########| 25/25 [00:00<00:00, 403.34it/s]

# %% [markdown]
# We have defined the potentials which we will use to generate data and  we created the dataset which we will use throughout the example
#
# Now we can generate data easily for our example. We will start by generating the data straight from the potentials before adding more complexity to the system

# %%
n_sims = 100
n_steps = 500
simple_data = pots.generate_data(n_sims, n_steps)
# Out:
# Running Simulations: 100%|##########| 100/100 [00:37<00:00,  2.68it/s]
# Classifying Simulation Outcomes: 100%|##########| 100/100 [00:00<?, ?it/s]
# Generating dataset
# Getting simulation labels for the generated data

# %% [markdown]
# We generated 100 simulations with 500 steps each. Let's see how the data looks like on these simulations, we will plot the relevant DW potential to see that it ends up in two different values after the given number of steps.

# %%
""" We have succesfully created test data for our MLTSA to analyze """
plt.plot(simple_data[0][:,pots.relevant_id,:].T, color="r", label="DW potential", alpha=0.1)
plt.plot(simple_data[0][:,-1,:].T, color="b", label="SW potential", alpha=0.1)
handles, labels = plt.gca().get_legend_handles_labels()
temp = {k:v for k,v in zip(labels, handles)}
plt.legend(temp.values(), temp.keys(), loc='best');
plt.xlabel("Simulation Steps")
plt.ylabel("Reaction Coordinate")
# Out:
# Text(0, 0.5, 'Reaction Coordinate')

# %% [markdown]
# Now we will generate complex data for our ML model to learn and we will visualize it as previously done. For this we simply call the generate_linear method on the dataset class which will return an array with the simulation data and the labels for each one of them.

# %%
n_simulations = 100
n_steps = 500
data, ans = oneD_dataset.generate_linear(n_simulations, n_steps)
# Out:
# Running Simulations: 100%|##########| 100/100 [00:35<00:00,  2.79it/s]
# Classifying Simulation Outcomes: 100%|##########| 100/100 [00:00<?, ?it/s]
# Generating dataset
# Getting simulation labels for the generated data

# %%
#We proceed to plot the values
fig, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].plot(data[0,0,:], color="r", label="Sim 1, feature 1")
axs[1].plot(data[0,1,:], color="r", label="Sim 1, feature 2")
axs[0].plot(data[1,0,:], color="b", label="Sim 2, feature 1")
axs[1].plot(data[1,1,:], color="b", label="Sim 2, feature 2")
axs[0].legend()
axs[1].legend()
axs[1].set_xlabel("Simulation Steps")
axs[1].set_ylabel("Reaction Coordinate")
axs[0].set_xlabel("Simulation Steps")
axs[0].set_ylabel("Reaction Coordinate")
# Out:
# Text(0, 0.5, 'Reaction Coordinate')

# %% [markdown]
# We see now that the features we plotted are noisy, when we do generate_linear we mixed the original simulation data for each potential (both SW and DW) with different mixing coefficient. We can even trace back which features have been mixed with our "known" relevant DW potential and see how it looks now.

# %%
relevant_dists = np.concatenate((np.where(pots.relevant_id == np.array(oneD_dataset.combinations).T[1])[0],
                          np.where(pots.relevant_id == np.array(oneD_dataset.combinations).T[0])[0]))
print("Features combined with the relevant DW are:", list(relevant_dists))
# Out:
# Features combined with the relevant DW are: [4, 35, 39, 79, 84, 92, 137, 165, 170, 51, 107, 123, 134, 156]

# %%
for feat in relevant_dists:
    print("Feature", feat,"- Potentials involved:",list(oneD_dataset.combinations[feat]))
    summ = np.array(oneD_dataset.mixing_coefs).T[feat][1] + np.array(oneD_dataset.mixing_coefs).T[feat][0]
    print("Pot1:", np.around(100 *np.array(oneD_dataset.mixing_coefs).T[feat][0]/summ, decimals=2), "%")
    print("Pot2:", np.around(100 *np.array(oneD_dataset.mixing_coefs).T[feat][1]/summ, decimals=2), "%")
# Out:
# Feature 4 - Potentials involved: [7, 13]
# Pot1: 13.19 %
# Pot2: 86.81 %
# Feature 35 - Potentials involved: [1, 13]
# Pot1: 98.5 %
# Pot2: 1.5 %
# Feature 39 - Potentials involved: [5, 13]
# Pot1: 41.27 %
# Pot2: 58.73 %
# Feature 79 - Potentials involved: [6, 13]
# Pot1: 52.33 %
# Pot2: 47.67 %
# Feature 84 - Potentials involved: [9, 13]
# Pot1: 76.78 %
# Pot2: 23.22 %
# Feature 92 - Potentials involved: [12, 13]
# Pot1: 72.56 %
# Pot2: 27.44 %
# Feature 137 - Potentials involved: [11, 13]
# Pot1: 25.03 %
# Pot2: 74.97 %
# Feature 165 - Potentials involved: [10, 13]
# Pot1: 52.88 %
# Pot2: 47.12 %
# Feature 170 - Potentials involved: [8, 13]
# Pot1: 70.23 %
# Pot2: 29.77 %
# Feature 51 - Potentials involved: [13, 18]
# Pot1: 47.66 %
# Pot2: 52.34 %
# Feature 107 - Potentials involved: [13, 22]
# Pot1: 47.79 %
# Pot2: 52.21 %
# Feature 123 - Potentials involved: [13, 24]
# Pot1: 81.46 %
# Pot2: 18.54 %
# Feature 134 - Potentials involved: [13, 14]
# Pot1: 55.97 %
# Pot2: 44.03 %
# Feature 156 - Potentials involved: [13, 19]
# Pot1: 57.95 %
# Pot2: 42.05 %

# %% [markdown]
# Since we got our simulations classified we can see how the different features look like for each feature, you can try changing the number to see other features:

# %%
#We can choose which feature to plot here
feature_to_plot = 84
plt.figure(figsize=(5,7))
for dat, answer in zip(data[:,feature_to_plot,:], ans):
    if answer == "IN":
        plt.plot(list(reversed(dat)), np.arange(0, len(dat)), color="blue", alpha=0.1)
    elif answer == "OUT":
        plt.plot(list(reversed(dat)), np.arange(0, len(dat)), color="r", alpha=0.1)
plt.ylabel("time (steps)")
plt.xlabel(r'$\alpha y^{*} + (1-\alpha)y$')
# Out:
# Text(0.5, 0, '$\\alpha y^{*} + (1-\\alpha)y$')

# %% [markdown]
# Now that we made sure our data is scrambled and it is ready to work with, we will simply format it according to what our ML model needs.
#
# Since we are using an MLP with the number of features as inputs we need to concatenate the frames of the different simulations one after the other in order to get our X. This input data (X) will have the shape of (n_frames, n_features). To get the target values (Y) to fit to, we will have to get the outcome labels (IN/OUT) from the simulations for each corresponding frame,  which will result in a Y with shape (n_frames).
#
# For this task we will use the PrepareData() method on our 1D dataset, this will give us the input data (X) and target values (Y) in an appropriate format to use. Additionally the method allows one to only use a particular range of data instead of the whole length which would be too easy for the ML approach to predict.

# %%
time_frame = [30, 60]

X, Y = oneD_dataset.PrepareData(data, ans, time_frame, mode="Normal")

print("Shape of X is:", X.shape)
print("Shape of Y is:", Y.shape)
print("X and Y have the same length:", len(X) == len(Y))
# Out:
# Shape of X is: (3000, 179)
# Shape of Y is: (3000,)
# X and Y have the same length: True

# %% [markdown]
# Our simulation data is ready to be used now, so we will import the necessary functions for applying our MLTSA. First we need the ML algorithm and the MLTSA methods.
#
# This module has full implementation with Scikit-Learn models so we can directly import them.

# %%
from MLTSA_sklearn.models import SKL_Train
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# Next step is to train the model on data, we use the SKL_Train() function which needs the classifier, X and Y data to fit.
# This classifier can be any within the SKlearn suite that uses the .fit() method and the .predict() method.
#
# We can simply call an Multi-Layer Perceptron from SK-learn and tune it as we want. In this case we will set the verbose to True and put a maximum number of iterations so it does not train for too long.
# Remember you can do this by hand but we just provided some wrappers to make it easier.

# %%
NN = MLPClassifier(random_state=1, verbose=True, max_iter=500) # You can set the verbose to false for less prints.

trained_NN, train_acc, test_acc = SKL_Train(NN, X, Y)
# Out:
# Iteration 1, loss = 0.67172456
# Iteration 2, loss = 0.66418579
# Iteration 3, loss = 0.66452053
# Iteration 4, loss = 0.66190772
# Iteration 5, loss = 0.66153023
# Iteration 6, loss = 0.66158045
# Iteration 7, loss = 0.66428863
# Iteration 8, loss = 0.66068378
# Iteration 9, loss = 0.66031439
# Iteration 10, loss = 0.66269283
# Iteration 11, loss = 0.66172516
# Iteration 12, loss = 0.66030210
# Iteration 13, loss = 0.66006778
# Iteration 14, loss = 0.66008769
# Iteration 15, loss = 0.65863190
# Iteration 16, loss = 0.66424417
# Iteration 17, loss = 0.65927385
# Iteration 18, loss = 0.66192128
# Iteration 19, loss = 0.65655369
# Iteration 20, loss = 0.65547330
# Iteration 21, loss = 0.65360642
# Iteration 22, loss = 0.65326209
# Iteration 23, loss = 0.65583321
# Iteration 24, loss = 0.65632206
# Iteration 25, loss = 0.65575362
# Iteration 26, loss = 0.65269644
# Iteration 27, loss = 0.65019395
# Iteration 28, loss = 0.65019171
# Iteration 29, loss = 0.65667289
# Iteration 30, loss = 0.65553901
# Iteration 31, loss = 0.64791749
# Iteration 32, loss = 0.64786182
# Iteration 33, loss = 0.64700237
# Iteration 34, loss = 0.64907060
# Iteration 35, loss = 0.65284414
# Iteration 36, loss = 0.64884106
# Iteration 37, loss = 0.64821547
# Iteration 38, loss = 0.64373445
# Iteration 39, loss = 0.64362893
# Iteration 40, loss = 0.64347208
# Iteration 41, loss = 0.64437787
# Iteration 42, loss = 0.64078068
# Iteration 43, loss = 0.63955228
# Iteration 44, loss = 0.64013678
# Iteration 45, loss = 0.63706138
# Iteration 46, loss = 0.65022273
# Iteration 47, loss = 0.64313948
# Iteration 48, loss = 0.63949093
# Iteration 49, loss = 0.63542897
# Iteration 50, loss = 0.63399840
# Iteration 51, loss = 0.63397665
# Iteration 52, loss = 0.64320443
# Iteration 53, loss = 0.64209022
# Iteration 54, loss = 0.63184189
# Iteration 55, loss = 0.62641583
# Iteration 56, loss = 0.63855412
# Iteration 57, loss = 0.63287319
# Iteration 58, loss = 0.64244584
# Iteration 59, loss = 0.62729856
# Iteration 60, loss = 0.63123295
# Iteration 61, loss = 0.62804604
# Iteration 62, loss = 0.62435048
# Iteration 63, loss = 0.61865841
# Iteration 64, loss = 0.62365316
# Iteration 65, loss = 0.62146609
# Iteration 66, loss = 0.61472374
# Iteration 67, loss = 0.61318717
# Iteration 68, loss = 0.61578939
# Iteration 69, loss = 0.61434100
# Iteration 70, loss = 0.61043228
# Iteration 71, loss = 0.61231845
# Iteration 72, loss = 0.61400066
# Iteration 73, loss = 0.61563358
# Iteration 74, loss = 0.60709507
# Iteration 75, loss = 0.60145041
# Iteration 76, loss = 0.60094105
# Iteration 77, loss = 0.59851733
# Iteration 78, loss = 0.60300316
# Iteration 79, loss = 0.59950610
# Iteration 80, loss = 0.59344859
# Iteration 81, loss = 0.59263340
# Iteration 82, loss = 0.60973031
# Iteration 83, loss = 0.58993702
# Iteration 84, loss = 0.61045346
# Iteration 85, loss = 0.59076753
# Iteration 86, loss = 0.58819759
# Iteration 87, loss = 0.58134117
# Iteration 88, loss = 0.57729459
# Iteration 89, loss = 0.57940791
# Iteration 90, loss = 0.58072548
# Iteration 91, loss = 0.57922274
# Iteration 92, loss = 0.57879542
# Iteration 93, loss = 0.57044437
# Iteration 94, loss = 0.57252385
# Iteration 95, loss = 0.56484183
# Iteration 96, loss = 0.58580187
# Iteration 97, loss = 0.58154575
# Iteration 98, loss = 0.56104682
# Iteration 99, loss = 0.55629512
# Iteration 100, loss = 0.55307769
# Iteration 101, loss = 0.55093280
# Iteration 102, loss = 0.56781705
# Iteration 103, loss = 0.55742762
# Iteration 104, loss = 0.56748572
# Iteration 105, loss = 0.54146145
# Iteration 106, loss = 0.56550815
# Iteration 107, loss = 0.54889218
# Iteration 108, loss = 0.54232127
# Iteration 109, loss = 0.53469876
# Iteration 110, loss = 0.53186988
# Iteration 111, loss = 0.54021831
# Iteration 112, loss = 0.52753074
# Iteration 113, loss = 0.53222783
# Iteration 114, loss = 0.53040056
# Iteration 115, loss = 0.52119579
# Iteration 116, loss = 0.53058479
# Iteration 117, loss = 0.52714981
# Iteration 118, loss = 0.51415605
# Iteration 119, loss = 0.51347402
# Iteration 120, loss = 0.50871410
# Iteration 121, loss = 0.50485298
# Iteration 122, loss = 0.51013319
# Iteration 123, loss = 0.51148991
# Iteration 124, loss = 0.50885934
# Iteration 125, loss = 0.50377787
# Iteration 126, loss = 0.49662559
# Iteration 127, loss = 0.49591286
# Iteration 128, loss = 0.49159317
# Iteration 129, loss = 0.48741347
# Iteration 130, loss = 0.50403883
# Iteration 131, loss = 0.49369966
# Iteration 132, loss = 0.48603148
# Iteration 133, loss = 0.47790817
# Iteration 134, loss = 0.48479107
# Iteration 135, loss = 0.47400412
# Iteration 136, loss = 0.48861679
# Iteration 137, loss = 0.47567917
# Iteration 138, loss = 0.46670267
# Iteration 139, loss = 0.47339119
# Iteration 140, loss = 0.46502298
# Iteration 141, loss = 0.46491875
# Iteration 142, loss = 0.45696569
# Iteration 143, loss = 0.45287524
# Iteration 144, loss = 0.45988900
# Iteration 145, loss = 0.45835939
# Iteration 146, loss = 0.44929598
# Iteration 147, loss = 0.44405046
# Iteration 148, loss = 0.44442957
# Iteration 149, loss = 0.44887424
# Iteration 150, loss = 0.44459315
# Iteration 151, loss = 0.43941782
# Iteration 152, loss = 0.44512556
# Iteration 153, loss = 0.44159429
# Iteration 154, loss = 0.43373947
# Iteration 155, loss = 0.44461009
# Iteration 156, loss = 0.42736756
# Iteration 157, loss = 0.42329362
# Iteration 158, loss = 0.42979962
# Iteration 159, loss = 0.41949342
# Iteration 160, loss = 0.41820496
# Iteration 161, loss = 0.41435583
# Iteration 162, loss = 0.41104669
# Iteration 163, loss = 0.41374056
# Iteration 164, loss = 0.41946561
# Iteration 165, loss = 0.40781818
# Iteration 166, loss = 0.40845835
# Iteration 167, loss = 0.41073917
# Iteration 168, loss = 0.40383210
# Iteration 169, loss = 0.41884887
# Iteration 170, loss = 0.45430828
# Iteration 171, loss = 0.39628424
# Iteration 172, loss = 0.39140442
# Iteration 173, loss = 0.39651914
# Iteration 174, loss = 0.39267252
# Iteration 175, loss = 0.40313607
# Iteration 176, loss = 0.41332553
# Iteration 177, loss = 0.39099308
# Iteration 178, loss = 0.37893877
# Iteration 179, loss = 0.37839373
# Iteration 180, loss = 0.39132814
# Iteration 181, loss = 0.37741967
# Iteration 182, loss = 0.37868569
# Iteration 183, loss = 0.37441142
# Iteration 184, loss = 0.36989778
# Iteration 185, loss = 0.36836833
# Iteration 186, loss = 0.36504102
# Iteration 187, loss = 0.36269384
# Iteration 188, loss = 0.37252958
# Iteration 189, loss = 0.37631185
# Iteration 190, loss = 0.35999581
# Iteration 191, loss = 0.35633057
# Iteration 192, loss = 0.36175598
# Iteration 193, loss = 0.37346382
# Iteration 194, loss = 0.36593367
# Iteration 195, loss = 0.35429254
# Iteration 196, loss = 0.35535996
# Iteration 197, loss = 0.35324075
# Iteration 198, loss = 0.37582242
# Iteration 199, loss = 0.34804561
# Iteration 200, loss = 0.34997101
# Iteration 201, loss = 0.35255691
# Iteration 202, loss = 0.34016313
# Iteration 203, loss = 0.34206149
# Iteration 204, loss = 0.36024385
# Iteration 205, loss = 0.35679196
# Iteration 206, loss = 0.34853300
# Iteration 207, loss = 0.35528879
# Iteration 208, loss = 0.33921816
# Iteration 209, loss = 0.33061146
# Iteration 210, loss = 0.33233433
# Iteration 211, loss = 0.33858933
# Iteration 212, loss = 0.32451355
# Iteration 213, loss = 0.33477219
# Iteration 214, loss = 0.34899873
# Iteration 215, loss = 0.32673084
# Iteration 216, loss = 0.33675737
# Iteration 217, loss = 0.32928210
# Iteration 218, loss = 0.32165825
# Iteration 219, loss = 0.31838478
# Iteration 220, loss = 0.33193487
# Iteration 221, loss = 0.31623391
# Iteration 222, loss = 0.31875799
# Iteration 223, loss = 0.33314858
# Iteration 224, loss = 0.32623030
# Iteration 225, loss = 0.31271462
# Iteration 226, loss = 0.30903772
# Iteration 227, loss = 0.31677475
# Iteration 228, loss = 0.32022668
# Iteration 229, loss = 0.32898456
# Iteration 230, loss = 0.32104992
# Iteration 231, loss = 0.31959330
# Iteration 232, loss = 0.32034586
# Iteration 233, loss = 0.30342792
# Iteration 234, loss = 0.31113800
# Iteration 235, loss = 0.31801074
# Iteration 236, loss = 0.29570386
# Iteration 237, loss = 0.29698903
# Iteration 238, loss = 0.29493499
# Iteration 239, loss = 0.29132475
# Iteration 240, loss = 0.29129285
# Iteration 241, loss = 0.29275953
# Iteration 242, loss = 0.31503528
# Iteration 243, loss = 0.30329151
# Iteration 244, loss = 0.28858430
# Iteration 245, loss = 0.29433905
# Iteration 246, loss = 0.29413857
# Iteration 247, loss = 0.28976277
# Iteration 248, loss = 0.28306679
# Iteration 249, loss = 0.28075748
# Iteration 250, loss = 0.28818007
# Iteration 251, loss = 0.28359567
# Iteration 252, loss = 0.30348737
# Iteration 253, loss = 0.32430698
# Iteration 254, loss = 0.31692386
# Iteration 255, loss = 0.29646594
# Iteration 256, loss = 0.28699419
# Iteration 257, loss = 0.28630463
# Iteration 258, loss = 0.29142921
# Iteration 259, loss = 0.27376367
# Iteration 260, loss = 0.27477773
# Iteration 261, loss = 0.27528283
# Iteration 262, loss = 0.27029988
# Iteration 263, loss = 0.26765298
# Iteration 264, loss = 0.26770451
# Iteration 265, loss = 0.26614980
# Iteration 266, loss = 0.26556008
# Iteration 267, loss = 0.26585598
# Iteration 268, loss = 0.26267843
# Iteration 269, loss = 0.26996040
# Iteration 270, loss = 0.26534068
# Iteration 271, loss = 0.27082113
# Iteration 272, loss = 0.27011352
# Iteration 273, loss = 0.27512807
# Iteration 274, loss = 0.25983440
# Iteration 275, loss = 0.26583733
# Iteration 276, loss = 0.25710722
# Iteration 277, loss = 0.26015901
# Iteration 278, loss = 0.26063176
# Iteration 279, loss = 0.25344735
# Iteration 280, loss = 0.25544960
# Iteration 281, loss = 0.25287899
# Iteration 282, loss = 0.26113725
# Iteration 283, loss = 0.25431994
# Iteration 284, loss = 0.25757966
# Iteration 285, loss = 0.25430928
# Iteration 286, loss = 0.25689888
# Iteration 287, loss = 0.25879896
# Iteration 288, loss = 0.25682414
# Iteration 289, loss = 0.24768762
# Iteration 290, loss = 0.25180439
# Iteration 291, loss = 0.24369167
# Iteration 292, loss = 0.27852985
# Iteration 293, loss = 0.25031514
# Iteration 294, loss = 0.24516540
# Iteration 295, loss = 0.24578462
# Iteration 296, loss = 0.24270780
# Iteration 297, loss = 0.26801535
# Iteration 298, loss = 0.24797478
# Iteration 299, loss = 0.24556486
# Iteration 300, loss = 0.23922531
# Iteration 301, loss = 0.23727198
# Iteration 302, loss = 0.25023914
# Iteration 303, loss = 0.24068721
# Iteration 304, loss = 0.23939855
# Iteration 305, loss = 0.23546543
# Iteration 306, loss = 0.23965280
# Iteration 307, loss = 0.23132443
# Iteration 308, loss = 0.24363838
# Iteration 309, loss = 0.24038581
# Iteration 310, loss = 0.23677287
# Iteration 311, loss = 0.24571832
# Iteration 312, loss = 0.22938835
# Iteration 313, loss = 0.22730100
# Iteration 314, loss = 0.22806004
# Iteration 315, loss = 0.23579636
# Iteration 316, loss = 0.23969465
# Iteration 317, loss = 0.22674184
# Iteration 318, loss = 0.22423878
# Iteration 319, loss = 0.22560002
# Iteration 320, loss = 0.22263347
# Iteration 321, loss = 0.22454029
# Iteration 322, loss = 0.21967242
# Iteration 323, loss = 0.23612117
# Iteration 324, loss = 0.22274800
# Iteration 325, loss = 0.22958891
# Iteration 326, loss = 0.21856951
# Iteration 327, loss = 0.23857402
# Iteration 328, loss = 0.22857582
# Iteration 329, loss = 0.22060687
# Iteration 330, loss = 0.21603514
# Iteration 331, loss = 0.22398928
# Iteration 332, loss = 0.21574011
# Iteration 333, loss = 0.21509276
# Iteration 334, loss = 0.23317957
# Iteration 335, loss = 0.22548089
# Iteration 336, loss = 0.22261645
# Iteration 337, loss = 0.22213457
# Iteration 338, loss = 0.23770373
# Iteration 339, loss = 0.21350402
# Iteration 340, loss = 0.21712652
# Iteration 341, loss = 0.21259463
# Iteration 342, loss = 0.22218698
# Iteration 343, loss = 0.24668979
# Iteration 344, loss = 0.22554660
# Iteration 345, loss = 0.21756061
# Iteration 346, loss = 0.20849814
# Iteration 347, loss = 0.21182157
# Iteration 348, loss = 0.21421801
# Iteration 349, loss = 0.20778699
# Iteration 350, loss = 0.20791215
# Iteration 351, loss = 0.24699269
# Iteration 352, loss = 0.22025406
# Iteration 353, loss = 0.21803733
# Iteration 354, loss = 0.20069114
# Iteration 355, loss = 0.20381802
# Iteration 356, loss = 0.21439094
# Iteration 357, loss = 0.28921376
# Iteration 358, loss = 0.21364453
# Iteration 359, loss = 0.20750297
# Iteration 360, loss = 0.21006424
# Iteration 361, loss = 0.21718708
# Iteration 362, loss = 0.22892100
# Iteration 363, loss = 0.21796211
# Iteration 364, loss = 0.20060905
# Iteration 365, loss = 0.20297311
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Accuracy on Train is 95.11111111111111
# Accuracy on Test set is 95.33333333333334
# Trained in  9.363238334655762 seconds

# %% [markdown]
# If you used the default options from this notebook, you should have gotten around 96% accuracy on training and 95% on test without breaking a sweat.
#
# In case you have doubts about the accuracy, we can do a simple validation test generating new data from scratch.

# %%
""" Time for Validation with new simulations """

#Generate 25 additional simulations data
data_val, ans_val = oneD_dataset.generate_linear(25, 500)

#Prepare for trial
X_val, Y_val = oneD_dataset.PrepareData(data_val, ans_val, time_frame, mode="Normal")

#Predict the new simulations on the already trained NN
Y_pred = trained_NN.predict(X_val)
val_acc = Y_val == Y_pred
val_acc = np.mean(val_acc)

print("Validation Accuracy is", val_acc*100)
# Out:
# Running Simulations: 100%|##########| 25/25 [00:09<00:00,  2.73it/s]
# Classifying Simulation Outcomes: 100%|##########| 25/25 [00:00<?, ?it/s]
# Generating dataset
# Getting simulation labels for the generated data
# Validation Accuracy is 87.46666666666667

# %% [markdown]
# Once we are happy about the training on our ML model we can move onto trying to detect those correlated features.
#
# For this we simply call the MLTSA() function on the data and the trained model.

# %%
from MLTSA_sklearn.MLTSA_code import MLTSA

#We Call the method on the data, labels and trained NN.
ADrop_train = MLTSA(data, ans, trained_NN, "Normal")
# Out:
# 100it [00:38,  2.63it/s]

# %% [markdown]
# ADrop means accuracy drop which is what we usually look for when trying to find important distances.
#
# The easiest way to detect those is plotting the values obtained.

# %%
plt.figure(figsize=(10,4))
plt.plot(ADrop_train*100, label="Training Accuracy Drop", color="C0")
plt.legend()
plt.xlabel("# Feature")
plt.ylabel("Accuracy (%)")
plt.ylim()
# Out:
# (96.50930000000002, 98.15269999999997)

# %% [markdown]
# Now for easier visualization, we included code to plot this to look like the original paper.
#
# This function will plot the MLTSA results in a manner which is easier to interpret and highlight the known to be correlated values to confirm the ML has detected them.

# %%
from MLTSA_sklearn.MLTSA_code import MLTSA_Plot

#We simply get the plot with this
MLTSA_Plot([ADrop_train], oneD_dataset, pots, errorbar=False)
# Out:
# Plotting Colorbar
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:224: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\pedro\PycharmProjects\MLTSA\MLTSA_sklearn\MLTSA_code.py:95: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# This plots shows the accuracy drop for every single feature after swapping them with their global mean accross simulations. The features highlighted with a coloured cross are correlated features having red as the most correlated (100%) and blue as the least (0%).
